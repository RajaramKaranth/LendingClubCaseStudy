# %%
# Data Cleaning

# mths_since_last_delinq column has 25682 NA values. Replaced with zero
# mths_since_last_record column has 36931 NA values. Replaced with zero
# desc column has 13149 blank values. However, those have corresponding valid purpose column values
# next_pymnt_d column has 38577 blank records
# collections_12_mths_ex_med column has either zero or NA as values. Hence deleted this column from the data set
# mths_since_last_major_derog column has only NA as values. Hence deleted this column from the data set
# annual_inc_joint column has only NA as values. Hence deleted this column from the data set
# dti_joint column has only NA as values. Hence deleted this column from the data set
# verification_status_joint column has only NA as values. Hence deleted this column from the data set
# acc_now_delinq column has only 0 as values. Hence deleted this column from the data set
# tot_coll_amt column has only NA as values. Hence deleted this column from the data set
# tot_cur_bal column has only NA as values. Hence deleted this column from the data set
# open_acc_6m column has only NA as values. Hence deleted this column from the data set
# open_il_6m column has only NA as values. Hence deleted this column from the data set
# open_il_12m column has only NA as values. Hence deleted this column from the data set
# open_il_24m column has only NA as values. Hence deleted this column from the data set
# mths_since_rcnt_il column has only NA as values. Hence deleted this column from the data set
# total_bal_il has only NA as values. Hence deleted this column from the data set
# il_util column has only NA as values. Hence deleted this column from the data set
# open_rv_12m column has only NA as values. Hence deleted this column from the data set
# open_rv_24m column has only NA as values. Hence deleted this column from the data set
# max_bal_bc column has only NA as values. Hence deleted this column from the data set
# all_util column has only NA as values. Hence deleted this column from the data set
# total_rev_hi_lim column has only NA as values. Hence deleted this column from the data set
# inq_fi column has only NA as values. Hence deleted this column from the data set
# total_cu_tl column has only NA as values. Hence deleted this column from the data set
# inq_last_12m column has only NA as values. Hence deleted this column from the data set
# acc_open_past_24mths column has only NA as values. Hence deleted this column from the data set
# avg_cur_bal column has only NA as values. Hence deleted this column from the data set
# bc_open_to_buy column has only NA as values. Hence deleted this column from the data set
# bc_util column has only NA as values. Hence deleted this column from the data set
# chargeoff_within_12_mths column has either zero or NA as values. Hence deleted this column from the data set
# delinq_amnt column has only 0 as values. Hence deleted this column from the data set
# mo_sin_old_il_acct column has only NA as values. Hence deleted this column from the data set
# mo_sin_old_rev_tl_op column has only NA as values. Hence deleted this column from the data set
# mo_sin_rcnt_rev_tl_op column has only NA as values. Hence deleted this column from the data set
# mo_sin_rcnt_tl column has only NA as values. Hence deleted this column from the data set
# mort_acc column has only NA as values. Hence deleted this column from the data set
# mths_since_recent_bc column has only NA as values. Hence deleted this column from the data set
# mths_since_recent_bc_dlq column has only NA as values. Hence deleted this column from the data set
# mths_since_recent_inq column has only NA as values. Hence deleted this column from the data set
# mths_since_recent_revol_delinq column has only NA as values. Hence deleted this column from the data set
# num_accts_ever_120_pd column has only NA as values. Hence deleted this column from the data set
# num_actv_bc_tl column has only NA as values. Hence deleted this column from the data set
# num_actv_rev_tl column has only NA as values. Hence deleted this column from the data set
# num_bc_sats column has only NA as values. Hence deleted this column from the data set
# num_bc_tl column has only NA as values. Hence deleted this column from the data set
# num_il_tl column has only NA as values. Hence deleted this column from the data set
# num_op_rev_tl column has only NA as values. Hence deleted this column from the data set
# num_rev_accts column has only NA as values. Hence deleted this column from the data set
# num_rev_tl_bal_gt_0 column has only NA as values. Hence deleted this column from the data set
# num_sats column has only NA as values. Hence deleted this column from the data set
# num_tl_120dpd_2m column has only NA as values. Hence deleted this column from the data set
# num_tl_30dpd column has only NA as values. Hence deleted this column from the data set
# num_tl_90g_dpd_24m column has only NA as values. Hence deleted this column from the data set
# num_tl_op_past_12m column has only NA as values. Hence deleted this column from the data set
# pct_tl_nvr_dlq column has only NA as values. Hence deleted this column from the data set
# percent_bc_gt_75 column has only NA as values. Hence deleted this column from the data set
# tax_liens column has either zero or NA as values. Hence deleted this column from the data set
# tot_hi_cred_lim column has only NA as values. Hence deleted this column from the data set
# total_bal_ex_mort column has only NA as values. Hence deleted this column from the data set
# total_bc_limit column has only NA as values. Hence deleted this column from the data set
# total_il_high_credit_limit column has only NA as values. Hence deleted this column from the data set

# %%
# Univariate Analysis #1 - number of loans by grade
import pandas as pd
import seaborn.objects as so
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
(
    so.Plot(loan, x="grade")
    .add(so.Bars(), so.Hist())
)
# Highest number of loans disbursed are of grade B, followed by grade A
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\518454556.py:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')

# %%
# Univariate Analysis #2 - loan installments preferred
import pandas as pd
import seaborn.objects as so
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
(
    so.Plot(loan, x="installment")
    .add(so.Bars(), so.Hist())
)
# the highest bins intallments opted are between 0 - 200 months and 200 - 400 months.
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\2294583860.py:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')

# %%
# Univariate Analysis #3 - Purpose for which most of the loans are taken 
import pandas as pd
import seaborn.objects as so
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
print(loan['purpose'].value_counts())
# Highest number of loan types are of type Debt consolidation followed by credit card loans
# Out:
# debt_consolidation    18641
# credit_card            5130
# other                  3993
# home_improvement       2976
# major_purchase         2187
# small_business         1828
# car                    1549
# wedding                 947
# medical                 693
# moving                  583
# vacation                381
# house                   381
# educational             325
# renewable_energy        103
# Name: purpose, dtype: int64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\4068059865.py:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')

# %%
# Univariate Analysis #4 - State where maximum number of loans disbursed 
import pandas as pd
import seaborn.objects as so
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
print(loan['addr_state'].value_counts())
# maximum number of loans disbursed in the state of California followed ny the state of New York
# Out:
# CA    7099
# NY    3812
# FL    2866
# TX    2727
# NJ    1850
# IL    1525
# PA    1517
# VA    1407
# GA    1398
# MA    1340
# OH    1223
# MD    1049
# AZ     879
# WA     840
# CO     792
# NC     788
# CT     751
# MI     720
# MO     686
# MN     615
# NV     497
# SC     472
# WI     460
# AL     452
# OR     451
# LA     436
# KY     325
# OK     299
# KS     271
# UT     258
# AR     245
# DC     214
# RI     198
# NM     189
# WV     177
# HI     174
# NH     171
# DE     114
# MT      85
# WY      83
# AK      80
# SD      64
# VT      54
# MS      19
# TN      17
# IN       9
# ID       6
# IA       5
# NE       5
# ME       3
# Name: addr_state, dtype: int64
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\3237595046.py:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')

# %%
# Univariate Analysis #5 - number of loans by length of employment
import pandas as pd
import seaborn.objects as so
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
(
    so.Plot(loan, x="emp_length")
    .add(so.Bars(), so.Hist())
)
# Maximum number of loans are availed by customers who are employed for 10+ years. The next highest bin is of the customers who are employed between 1 and 2 years
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\1353906532.py:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')

# %%
# Bivariate Analysis #1 - Corelation between the delinquency and the number of open credit lines customer has
import pandas as pd
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
loan2 = pd.DataFrame(loan[['delinq_2yrs','open_acc']])

loan2.corr()

# Number of open credit lines do not have a very strong correlation with delinquency
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\4106122248.py:4: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
#              delinq_2yrs  open_acc
# delinq_2yrs     1.000000  0.011656
# open_acc        0.011656  1.000000

# %%
# Bivariate Analysis #2 - Corelation between the delinquency and the dti
import pandas as pd
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
loan2 = pd.DataFrame(loan[['delinq_2yrs','dti']])

loan2.corr()

# In the given dataset, dti is found to be lower in the delinquent cases
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\2333477458.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
#              delinq_2yrs       dti
# delinq_2yrs     1.000000 -0.034452
# dti            -0.034452  1.000000

# %%
# Bivariate Analysis #3 - Corelation between the delinquency and the principal outstanding
import pandas as pd
loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
loan2 = pd.DataFrame(loan[['mths_since_last_delinq','out_prncp']])

loan2.corr()

# months since delinquency is inversely correlated with the repayment. recent delinquencies indicates chances of default
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_24636\1094909339.py:3: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv(r'C:\Skill Building\Upgrad EPGP Machine Learning and Artifical Intelligence\Lending club case study\loan.csv')
#                         mths_since_last_delinq  out_prncp
# mths_since_last_delinq                1.000000  -0.012297
# out_prncp                            -0.012297   1.000000

# %% [markdown]
# pip show pandas
